# %% [markdown]
# <a href="https://colab.research.google.com/github/NishanChy733689/boxplot/blob/main/Boxplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
var=sns.load_dataset("tips")

# %%
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style='whitegrid')
sns.boxplot(x=var.day,y=var.total_bill,order=['Fri','Sun','Thur','Sat'],
            showmeans=True,meanprops={'marker':"+",'markeredgecolor':"b"} ,linewidth=3,palette='plasma')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set(style='whitegrid')
sns.boxplot(x=var.total_bill,y=var.day,order=['Fri','Sun','Thur','Sat'],
            showmeans=True,meanprops={'marker':"+",'markeredgecolor':"b"} ,linewidth=3,palette='plasma')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.set(style='whitegrid')
sns.boxplot(var.total_bill)
# Out:
# <Axes: >
